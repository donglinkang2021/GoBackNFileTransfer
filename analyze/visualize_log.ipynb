# %%
from visualize import get_dataframe_log, plot_log

log_file = 'sender.log'
df_log = get_dataframe_log(log_file)
df_log.head()
# Out:
#                  time action pdu_type  frame_no  ack_no  data_size status
# 0 2024-04-17 22:16:18   Send     FILE         1       1         21    New
# 1 2024-04-17 22:16:18   Recv      ACK         1       2          0     OK
# 2 2024-04-17 22:16:19   Send     FILE         2       2       1024    New
# 3 2024-04-17 22:16:19   Send     FILE         3       2       1024    New
# 4 2024-04-17 22:16:19   Send     FILE         4       2       1024    New

# %%
save_dir = 'plots'
attributes = ['status', 'action', 'pdu_type']
show_values = ['data_size', 'frame_no']
for show_value in show_values:
    for attribute in attributes:
        plot_log(df_log, attribute, show_value, save_dir)
